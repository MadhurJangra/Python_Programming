# %% [markdown]
# # Experiment -1

# %% [markdown]
# python Installation Process:
#
# * Open your browser.
#
# * Go to the official website:
#          https://www.python.org
#
# * Click on Downloads.
#
# * Click the yellow button:
#          Download Python (latest version)

# %%
print("Hello everyone !!")

# %%
print('''hello
      world''')

# %%
print('''Hello
                 world''')

# %%
print("Rohit’s date of birth is 12\05\1999")

# %% [markdown]
# Part one Explanation:
#
# * print() function displays output.
#
# * \n creates new line (we used separate print instead).
#
# * \\ is used because \ is special character in Python.
#
# * We used single quotes inside double quotes to avoid error.

# %%
x="Hello"
print(x)

# %% [markdown]
# Part Two Explanation:
#
# * x is a variable.
#
# * "Hello" is a string.
#
# * print(x) prints the stored value.

# %%
a=10
b=1.2
c="hello"
d=True
print(a)
print(b)
print(c)
print(d)

# %% [markdown]
# Part Three Explanation:
#
# * Assign Different types of data types
#
# * print then using The print() Function

# %%
a = "Madhur"
b = "Jangra"

print(a + " " + b)

# %% [markdown]
# Part Four Explanation:
#
# * (+) is used for string concatenation.
#
# * " " adds space between names.

# %%
first_name = "Madhur"
nickname = "MJ"
last_name = "Jangra"

print(first_name + " (" + nickname + ") " + last_name)

# %% [markdown]
# Part five explanation:
#
# * Parenthesis printed as normal characters.
#
# * Strings are combined using (+).

# %%
name = "MADHUR JANGRA"
sap_id = 500069944
dob = "12 Oct 2005"
address1 = "UPES"
address2 = "Bidholi Campus"
pincode = 248007
programme = "AI & ML"
semester = 2

print("NAME:", name)
print("SAP ID:", sap_id)
print("DATE OF BIRTH:", dob)
print("ADDRESS:", address1)
print("Secondary ADDRESS:", address2)
print("Pincode:", pincode)
print("Programme:", programme)
print("Semester:", semester)

# %% [markdown]
# Explanation part six:
#
# * We declared variables for each detail.
#
# * Used indentation spaces inside print to match format.
#
# * Comma , automatically adds space between text and variable.
