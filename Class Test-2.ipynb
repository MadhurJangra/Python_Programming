# %% [markdown]
# # Class test Python

# %% [markdown]
# Question 1

# %%
class student:
    school_name="UPES"
    def __init__(self,name,age):
        self.name=name
        self.age=age
student1=student("Aman",20)
student2=student("Riya",21)

print("school",student1.school_name)
print("school",student2.school_name)
print("student 1",student1.name,student1.age)
print("student 2",student2.name,student2.age)

# %% [markdown]
# Question 2

# %%
class employee:
    company="ABC Ltd"
    def __init__(self,name,age):
        self.name=name
        self.salary=salary
    def show_details(self):
        print("Name",self.name,"salary",self.salary,"company",self.company)

    def change_Company(cls,new_name):
        cls.company=new_name
e1=employee("aman",50000)
e2=employee("aromal",60000)
print("Before changes")
el.show_details()
e2.show_details()
employee.change_company(XYZ pvt ltd)
print("after changes")
e1.show_details()
e2.show_details()

# %% [markdown]
# Question 3

# %%
class Mathhelper:
    def is_even(Num):
        return num%2==0
print(Mathhelper.is_even(8))
print(Mathhelper.is_even(5))

# %% [markdown]
# Question 4

# %%
class BankAccount:
    def __init__(self,name,balance):
        self.name=nameself.__balance=balance
    def deposit(self,amount):
        if amount >0:
            self.__balance=balance+amount
            print(f"Deposited:{amount}")
        else:
            print("invalid amount")
    def withdrawl(self,amount):
        if amount <=self.__balance:
            self.__balance-=amountprint(f"withdrawn:{amount}")
        else:
            print("insuffitient balance")
    def show_balance(self):
        print(f"Balance:{self.__balance}")

acc=BankAccount("Aman",1000)

acc.show_balance()
acc.deposit(500)
acc.show_balance()
acc.withdrawl(200)
acc.show_balance()

# %% [markdown]
# Question 5:
