# %% [markdown]
# # question 1

# %%
def top_k(items,k):
    return sorted(items,key=lambda x:x[1],reverse = True)[:k]
items = [("A", 90), ("B", 95), ("C", 95), ("D", 85)]
k=2
print(top_k(items,k))

# %% [markdown]
# # Ouestion 2

# %%
def Word_Counter(pairs):
    result={}
    for catagory,word in paris:
        if category not in result:
            result[catagory]={}
        if word not in result[catagory]:
            result[catagory][word]=0
        result[catagory][word]+=1
    return result
pairs = [("sports","win"), ("sports","win"), ("tech","ai")]
print(Word_Counter(pairs))

# %% [markdown]
# # Ouestion 3

# %%
def missing_number(Num):
    n=len(Num)
    actual_sum=sum(Num)
    expected_sum=n * (n + 1) // 2
    return expected_sum,actual_sum
Num=[3, 0, 1]
print(missing_number(Num))

# %% [markdown]
# # Question 4

# %%
def unique(values,lst=None):
    if lst is None :
        lst=[]
    if values not in lst:
        lst=values.append(lst)

# %% [markdown]
# # Question 5

# %%
def average(steam,w):
result=[]
window_sum=0
for i in range (len(steam)):
    if i>=w:
        window_sum
