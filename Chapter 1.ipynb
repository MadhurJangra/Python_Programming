# %% [markdown]
# # Chapter 1 — Getting Started with Python

# %% [markdown]
# Introduction to Python
# Python is an interpreted, object-oriented, high-level programming language with dynamic semantics. Its high-level built in data structures, combined with dynamic typing and dynamic binding, make it very attractive for Rapid Application Development, as well as for use as a scripting or glue language to connect existing components together. Python’s simple, easy to learn syntax emphasizes readability and therefore reduces the cost of program maintenance. Python supports modules and packages, which encourages program modularity and code reuse. The Python interpreter and the extensive standard library are available in source or binary form without charge for all major platforms, and can be freely distributed."

# %%
a=20
print(a)
# Out:
# 20

# %% [markdown]
# # What is interactive programming in python?

# %% [markdown]
# Python in its intractive mode is when we create a enviornment where the codes are executed line by line and immediately

# %% [markdown]
# # What is script programming in python?

# %% [markdown]
# When we submitt the script to the compiler using a helper command. In the case of python the terminal command is "python - file name"

# %% [markdown]
# # Interactive Python in Jupyter

# %%
a = 30
b = 20
print("What is the product of a and b")
print(a*b)
# Out:
# What is the product of a and b
# 600

# %% [markdown]
# # Script mode in Jupyter Notebook

# %%
# !python test1.py
# Out:
# Hello world !!

# %% [markdown]
# # Dynamic Types in Python

# %% [markdown]
# Python as a script or language is what " Dynamically Typed", meaning the varriable are declared during runtime and there dataype is not explicilty specified.

# %%
a=30

# %%
a ="Vibhu"

# %%
a[1]
# Out:
# 'i'

# %%
a[1]="v"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 a[1]="v"
#
# TypeError: 'str' object does not support item assignment

# %%
a= 20
print(type(a))
a = 20/100
print(type(a))
a = "Text"
print(type(a))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %% [markdown]
# # What is the command to check the data type?

# %% [markdown]
# The Command used to check the data type of a variable is type()

# %% [markdown]
# # What are immutable data types?

# %% [markdown]
# immutable are those data types whos values cannot be changed once entered

# %% [markdown]
# Some Examples of immutable data types :-

# %% [markdown]
# 1 --> Integer (int)
#
# 2 --> Floating Point (float)
#
# 3 --> boolean (bool)
#
# 4 --> string (str)
#
# 5 --> Tuples

# %%
a="abcd"
print(a)
a="a7cd"
print(a)
# Out:
# abcd
# a7cd

# %% [markdown]
# # What is a tuple?

# %%
a =(2,3)
print(a[0])
print(type(a))
# a[1] =4
# Out:
# 2
# <class 'tuple'>

# %%
a =(2,3)
print(a[0])
print(type(a))
a[1] =4
# Out:
# 2
# <class 'tuple'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       2 print(a[0])
#       3 print(type(a))
# ----> 4 a[1] =4
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # Python is an Object-Oriented Language

# %% [markdown]
# In Python, everything is an object.
# That means the following are also objects:

# %% [markdown]
# integers → 10
#
# strings → "hello"
#
# lists → [1,2,3]
#
# functions → print, len
#
# classes → str, list
#
# even modules → math, os

# %% [markdown]
# So, in Python:

# %% [markdown]
#               Data + Behavior are represented using objects.

# %% [markdown]
# # What is an Object in Python?
# Definition (theoretical)
#
#      An object is a runtime entity that has:
#
#      Identity → unique memory reference (id())
#
#      Type → what kind of object it is (type())
#
#      Value / State → actual data stored
#
# Example:

# %%
x = 10  
print(id(x)) # identity  
print(type(x)) # type  
print(x) # value
# Out:
# 140718194914712
# <class 'int'>
# 10

# %% [markdown]
# Internally:
#
#                 10 is an object of class int
#                 int itself is also an object (a class object)
